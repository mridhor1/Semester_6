# %% [markdown]
# # Probabilistic Neural Network : Contoh Kasus
# [Iqbal Basyar](https://github.com/underground-11), 2018
#
# *Notebook ini digunakan untuk referensi tugas 1.3 Machine Learning : PNN* <br>
# Deksripsi tugas : [link](https://github.com/underground-11/Semester_6/blob/master/Asdos%20Machine%20Learning/Tugas%203%20Machine%20Learning/Tugas1.3.pdf) <br>
# Data Train :  [link](https://github.com/underground-11/Semester_6/blob/master/Asdos%20Machine%20Learning/Tugas%203%20Machine%20Learning/data_train_PNN.txt) <br>
# Data Test (no label): [link](https://github.com/underground-11/Semester_6/blob/master/Asdos%20Machine%20Learning/Tugas%203%20Machine%20Learning/data_test_PNN.txt) <br>

# %%
# Kebutuhan library
import numpy as np
import pandas as pd
import plotly
from plotly.offline import *
from plotly.graph_objs import *
import plotly.graph_objs as go
from plotly import __version__
print ('Plotly Version : ',__version__) # requires version >= 1.9.0
init_notebook_mode(connected=True) #biar bisa inline plot plotly

import matplotlib
import matplotlib.pyplot as plt
# Out:
# Plotly Version :  2.4.0
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## 1. Load data to Dataframe

# %%
dataTrain = pd.read_csv('data_train_PNN.txt', delimiter = "\t")
dataTest = pd.read_csv('data_test_PNN.txt', delimiter = "\t")

# %% [markdown]
# Pisahkan dataTrain untuk mempermudah plot

# %%
kelas1 = dataTrain.loc[dataTrain['label'] == 0]
kelas2 = dataTrain.loc[dataTrain['label'] == 1]
kelas3 = dataTrain.loc[dataTrain['label'] == 2]

# %% [markdown]
# ## 2. Plot the data

# %%
trace1 = go.Scatter3d(
    name = 'kelas 0',
    x=kelas1['att1'],
    y=kelas1['att2'],
    z=kelas1['att3'],
    mode='markers',
    marker=dict(
        size=12,
        line=dict(
            color='rgba(217, 217, 0, 0.14)',
            width=0.2
        ),
        opacity=0.9
    )
)

trace2 = go.Scatter3d(
    name = 'kelas 1',
    x=kelas2['att1'],
    y=kelas2['att2'],
    z=kelas2['att3'],
    mode='markers',
    marker=dict(
        size=12,
        line=dict(
            color='rgba(217, 217, 217, 0.14)',
            width=0.2
        ),
        opacity=0.9
    )
)

trace3 = go.Scatter3d(
    name = 'Kelas 2',
    x=kelas3['att1'],
    y=kelas3['att2'],
    z=kelas3['att3'],
    mode='markers',
    marker=dict(
        size=12,
        line=dict(
            color='rgba(217, 217, 217, 0.14)',
            width=0.2
        ),
        opacity=0.9
    )
)

data = [trace1, trace2, trace3]

this_layout = go.Layout(
    title = 'Data Train',
#     height = '800' ,
    scene = dict(
        xaxis = dict(
            title='Att 1'),
        yaxis = dict(
            title='Att 2'),
        zaxis = dict(
            title='Att 3'),),
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=25
    )
)


fig = go.Figure(data=data, layout=this_layout)
plot(fig, filename='Data Train Scatter')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\offline\offline.py:459: UserWarning:
#
# Your filename `Data Train Scatter` didn't end with .html. Adding .html to the end of your file.
# 'file://G:\\project jupyter notebook\\Machine Learning Asdos\\Tugas 3 Machine Learning\\Data Train Scatter.html'

# %% [markdown]
# ## 3 Fungsi-Fungsi
# Fungsi fungsi yang digunakan dalam PNN antara lain :
# $$ \large f(x; \sigma, w) = e^{-\frac{1}{2}(\frac{x - w}{\sigma})^2} = e^{-\frac{(x - w)^2}{2\sigma^2}} $$
#
# $$ \large f(x; \sigma) = \frac{1}{n\sigma} \sum_{k=1}^{n} e^{-\frac{(x - x_k)^2}{\sigma^2}} $$
#
# $$ \large f(\textbf{x}; \sigma) =
# \frac{1}{(2\pi)^\frac{p}{2}  \sigma^p n} \sum_{k=1}^{n} e^ {- \large \frac{||  \textbf{x} - \textbf{x}_k  ||^2}{\sigma^2}} $$
#
#
# $$ norm {a} $$
# Keterangan : <br>
#     $w$: nilai yang diinginkan (data) atau pusat puncak<br>
#     $\sigma$: simpangan baku (disebut _Gaussian RMS width_), yang merepresentasikan lebar kurva yang dihasilkan.
#
# Dalam python fungsi ini dapat ditulis dengan:

# %%
def gaussian_pdf1(x, sigma, w):
    return np.exp( -(x - w)**2 / (2 * sigma**2) )


def gaussian_pdf2(x, sigma, dataTrain):
    p = len(x[0])
    n = len (x)
    
    total = 0
    for i in dataTrain :
        y = (x-i)**2
        y = np.exp(-y / sigma**2)
        total += y 
        
    return (1/(2* 3.14)**(p/2) * sigma**p *n)

# %%
sigma = 0.1
w = 0.5
x = np.linspace(w - 2, w + 2, 100)
fig = plt.figure('Fungsi Gaussian')
ax = fig.add_subplot(111)
ax.set_title('Fungsi Gaussian dengan $\sigma = %s, w = %s$' % (sigma, w))
ax.set_xlabel('$x$')
ax.set_ylabel('$f(x; \sigma, w)$')
ax.plot(x, [gaussian_pdf1(i, sigma, w) for i in x])
plt.show()

# %%
def pdf(data1, data2):
    result = 1
    return result

def G(F):
    sums = np.sum(F)
    return sums / len(F)

# %% [markdown]
# # B Pengujian
# ## B1.a Load data latih dan data uji

# %%
dataTest = pd.read_csv('data_test_PNN.txt', delimiter = "\t")
print (dataTest)
# Out:
#         att1      att2      att3
# 0   2.067345  2.509013  2.219507
# 1   1.868864  1.469633  2.734258
# 2   3.291033  2.391380  3.330830
# 3   1.806889  1.223557  1.515428
# 4   3.375024  1.660650  2.628991
# 5   0.955480  2.080066  1.858635
# 6   2.705724  3.087108  2.806428
# 7  -0.926318  0.562016  1.400771
# 8   1.600653  1.241732  1.564803
# 9   2.698275  2.110522  2.331000
# 10 -2.246458  2.550421  2.129057
# 11 -0.523639  0.640538  2.050121
# 12 -1.360271  0.949612  1.636638
# 13 -0.444209  0.951468  2.950982
# 14 -1.657612  1.540412  1.875963
# 15  2.746709 -1.982019 -1.257974
# 16 -1.975928  1.509508  1.610377
# 17 -2.482624  3.146963  1.717581
# 18 -1.639923  3.529366  3.859618
# 19 -1.453451  0.957199  0.901966
# 20  0.260257  1.402879 -2.260416
# 21  2.222264 -2.526582 -1.961826
# 22  1.841392 -2.825155 -1.436275
# 23  2.365692  1.464163  1.497261
# 24  1.315004  1.191013  1.340270
# 25  1.603502 -2.779129 -1.535779
# 26  1.973161 -0.238890 -2.442980
# 27  2.216305 -1.098281 -1.730588
# 28  1.981303 -0.595039 -1.115682
# 29  1.150706  3.355631  0.948367

# %%
dataTrain = pd.read_csv('data_train_PNN.txt', delimiter = "\t")
dataTest = pd.read_csv('data_test_PNN.txt', delimiter = "\t")
trace = go.Table(
    header=dict(values=dataTrain.columns,
                fill = dict(color='#C2D4FF'),
                align = ['left'] * 5),
    cells=dict(values=
038899, 3.35563055], [2.2195074790000002, 2.7342581669999997, 3.330829987, 1.5154282140000002, 2.628990989, 1.858634946, 2.806427525, 1.400770624, 1.564802596, 2.331000298, 2.1290566269999998, 2.050121172, 1.636638489, 2.950982205, 1.8759633830000002, -1.25797398, 1.610377304, 1.717581211, 3.8596179910000004, 0.901966486, -2.260416267, -1.961825984, -1.4362749869999998, 1.49726079, 1.340269696, -1.535778699, -2.4429804269999997, -1.730587956, -1.11568158, 0.9483669090000001]], "fill": {"color": "#F5F8FF"}, "align": ["left", "left", "left", "left", "left"]}}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ## B.1.b Klasifikasi

# %% [markdown]
# ## B.1.c Output ke prediksi.txt

# %%
output = dataTest.round(9)
output['label'] = dataTrain['label']

trace = go.Table(
    header=dict(values=output.columns,
                fill = dict(color='#C2D4FF'),
                align = ['left'] * 5),
    cells=dict(values=[output.att1, output.att2, output.att3, output.label],
               fill = dict(color='#F5F8FF'),
               align = ['left'] * 5))


data = [trace] 
iplot(data, filename = 'Data Test')
# Out:
# <div id="3d9001bf-7264-41c9-b5bd-b79ef502db8c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3d9001bf-7264-41c9-b5bd-b79ef502db8c", [{"type": "table", "header": {"values": ["att1", "att2", "att3", "label"], "fill": {"color": "#C2D4FF"}, "align": ["left", "left", "left", "left", "left"]}, "cells": {"values": [[2.067345164, 1.868863749, 3.291033307, 1.806889438, 3.375024438, 0.955479519, 2.705724469, -0.926318163, 1.600653256, 2.698274567, -2.24645826, -0.523638988, -1.360270759, -0.444208881, -1.65761181, 2.746709361, -1.975928475, -2.4826244, -1.639922769, -1.453451288, 0.260257315, 2.222263608, 1.841392357, 2.365692188, 1.315004283, 1.603501755, 1.973160654, 2.216305351, 1.981302845, 1.150705759], [2.50901315, 1.469632837, 2.391379862, 1.223556992, 1.660650004, 2.080066049, 3.087108099, 0.562016319, 1.241731705, 2.110521958, 2.550420596, 0.640538172, 0.949612039, 0.951467511, 1.540411894, -1.982018624, 1.509507719, 3.146963021, 3.529366453, 0.957199271, 1.40287932, -2.526582165, -2.825154713, 1.464163128, 1.191012511, -2.779129492, -0.238890147, -1.0982807, -0.595038899, 3.35563055], [2.219507479, 2.734258167, 3.330829987, 1.515428214, 2.628990989, 1.858634946, 2.806427525, 1.400770624, 1.564802596, 2.331000298, 2.129056627, 2.050121172, 1.636638489, 2.950982205, 1.875963383, -1.25797398, 1.610377304, 1.717581211, 3.859617991, 0.901966486, -2.260416267, -1.961825984, -1.436274987, 1.49726079, 1.340269696, -1.535778699, -2.442980427, -1.730587956, -1.11568158, 0.948366909], [2, 2, 2, 2, 0, 2, 0, 2, 1, 0, 0, 1, 0, 0, 2, 2, 2, 0, 2, 0, 1, 1, 2, 1, 1, 2, 1, 2, 1, 2]], "fill": {"color": "#F5F8FF"}, "align": ["left", "left", "left", "left", "left"]}}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
output.to_csv('output.txt', header=True, index=False, sep='\t', mode='a')

# %% [markdown]
# ## B.1.d Petunjuk pengujian (Readme.txt)

# %% [markdown]
# ## B.2 Akurasi (Terhadap data validasi)
