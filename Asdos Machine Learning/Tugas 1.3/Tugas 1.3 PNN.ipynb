# 138  -3.687.673.518   2.983.932.428   2.046.969.378      1
# 139    -0.881789427     175.163.259   2.783.774.128      1
# 140   1.273.900.923   3.194.223.921   1.588.173.197      2
# 141  -2.326.481.887   2.879.855.643   1.918.376.196      1
# 142     0.000186137   1.405.577.335     0.451571874      0
# 143   1.708.787.499    -0.749964868     0.254498934      2
# 144   1.664.034.377   2.577.605.957   1.471.001.455      0
# 145   2.428.942.144  -2.031.466.714     -0.03588727      2
# 146     0.516294256   2.205.905.652   1.793.809.926      0
# 147    -0.212366592    -0.249615677    -0.578701058      2
# 148   1.332.889.756   1.071.312.782   1.394.183.437      0
# 149   1.556.650.742  -2.433.995.499    -234.415.941      2
#
# [150 rows x 4 columns]

# %%
at1 = data['att1']
at2 = data['att2']
at3 = data['att3']
kelas = data['label']

print (at3)
# Out:
# 0        -0.883643654
# 1      -3.151.888.504
# 2      -3.081.089.332
# 3      -2.449.536.648
# 4       2.078.646.621
# 5       3.537.702.646
# 6       1.384.366.034
# 7      -1.695.142.201
# 8       1.057.048.079
# 9       2.333.581.582
# 10      1.571.322.775
# 11      3.067.792.994
# 12      3.331.670.469
# 13        202.562.734
# 14     -2.996.956.943
# 15     -1.532.058.083
# 16       -0.342372116
# 17      2.179.584.585
# 18     -2.645.521.793
# 19      1.862.774.551
# 20      2.118.886.432
# 21         17.537.022
# 22     -1.901.887.829
# 23      1.885.271.015
# 24      1.063.153.157
# 25       -0.260996347
# 26      2.503.186.315
# 27      2.110.485.973
# 28      3.208.465.176
# 29      2.330.462.956
#             ...
# 120    -1.580.053.995
# 121      -172.686.199
# 122    -1.398.754.626
# 123     3.034.340.831
# 124    -1.155.505.013
# 125    -1.788.378.768
# 126    -1.322.990.958
# 127     2.870.168.614
# 128     1.593.446.482
# 129    -1.933.716.314
# 130     2.641.720.491
# 131     2.068.231.278
# 132     2.921.802.938
# 133      -0.078094521
# 134     2.461.125.254
# 135    -1.862.856.376
# 136     1.596.729.383
# 137     3.065.885.018
# 138     2.046.969.378
# 139     2.783.774.128
# 140     1.588.173.197
# 141     1.918.376.196
# 142       0.451571874
# 143       0.254498934
# 144     1.471.001.455
# 145       -0.03588727
# 146     1.793.809.926
# 147      -0.578701058
# 148     1.394.183.437
# 149      -234.415.941
# Name: att3, Length: 150, dtype: object

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
for c, m, zlow, zhigh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zlow, zhigh)
    ax.scatter(xs, ys, zs, c=c, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-0872e108506f> in <module>()
#       9 # defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#      10 for c, m, zlow, zhigh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
# ---> 11     xs = randrange(n, 23, 32)
#      12     ys = randrange(n, 0, 100)
#      13     zs = randrange(n, zlow, zhigh)
#
# NameError: name 'randrange' is not defined
